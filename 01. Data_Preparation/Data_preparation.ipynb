# %% [markdown]
# # Data Preparation

# %% [markdown]
# # Customers files
#
# We receive the trade lanes to be quoted in different formats (see below). The idea in a future version of Reverse Logistics is to create a dictionary with the different formats for each customer. We will start building it as we receive the documents from our customers. In this first version, we will focus in two customers, A and B. First of all we will try to match lanes within the same tender (i.e.g Customer A), then we will try to match customer A vs Customer B and finally, we will try to combine the lanes with our company's volume.

# %% [markdown]
# ## Tender information

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
route_customerA = 'Customer_A.xlsx'

Customer_A = pd.read_excel(route_customerA)
Customer_A.head()
# Out:
#                                              Item ID             Lane type  \
# 0  PortNhava Sheva (Jawaharlal Nehru)PortDar Es S...  Full year allocation
# 1                    DoorCali DoorPortLimaLabelsHC40  Full year allocation
# 2           PortTianjinPortManzanilloSteel SheetDV20             benchmark
# 3            DoorCali DoorPortCallaoYeast mediumDV40  Full year allocation
# 4                      PortAntwerpPortCallaoMaltDV40             benchmark
#
#              Bid type ABI origin zone              origin region origin type  \
# 0  Alternative 1 Bids            APAC        Middle & South Asia        Port
# 1  Alternative 1 Bids             MAZ  South America North Coast        Door
# 2  Alternative 1 Bids            APAC          Central East Asia        Port
# 3  Alternative 1 Bids             MAZ  South America North Coast        Door
# 4  Alternative 1 Bids             EUR          North West Europe        Port
#
#   origin country  EHO origin port code                origin port name  \
# 0          India   IN            INNSA  Nhava Sheva (Jawaharlal Nehru)
# 1       Colombia  USF              NaN                             NaN
# 2          China  CNS            CNZZZ                         Tianjin
# 3       Colombia  USF              NaN                             NaN
# 4        Belgium  NLR            BEANR                         Antwerp
#
#                  ...                 LSS (Low Sulfur Surcharge) on carriage  \
# 0                ...                                        NaN         NaN
# 1                ...                                        NaN         NaN
# 2                ...                                        NaN         NaN
# 3                ...                                        NaN         NaN
# 4                ...                                        NaN         NaN
#
#   any additional cost per container Demurrage + detention@origin pre-carriage  \
# 0                               NaN                          NaN          NaN
# 1                               NaN                          NaN          NaN
# 2                               NaN                          NaN          NaN
# 3                               NaN                          NaN          NaN
# 4                               NaN                          NaN          NaN
#
#   OTHC.1 Ocean freight+BAF+LSS+any additional cost per container DTHC.1  \
# 0    NaN                                                NaN         NaN
# 1    NaN                                                NaN         NaN
# 2    NaN                                                NaN         NaN
# 3    NaN                                                NaN         NaN
# 4    NaN                                                NaN         NaN
#
#   on-carriage Demurrage + detention@destination
# 0         NaN                               NaN
# 1         NaN                               NaN
# 2         NaN                               NaN
# 3         NaN                               NaN
# 4         NaN                               NaN
#
# [5 rows x 88 columns]

# %%
route_customerB = 'Customer_B.xlsx'

Customer_B = pd.read_excel(route_customerB)
Customer_B.head()
# Out:
#   Lane ID Route Status Movement Type Container Type From Town  \
# 0    1089     Existing  Port to Port         20' DV  Makassar
# 1    1090     Existing  Port to Port         20' DV  Makassar
# 2    1093     Existing  Port to Port         20' RF  Shanghai
# 3    1094     Existing  Port to Port         40' RF  Shanghai
# 4    1095     Existing  Port to Port         20' RF  Shanghai
#
#   Preferred Port/Ramp/ICD of Loading Origin Zip Code From country From Region  \
# 0                           Makassar             NaN    Indonesia        APAC
# 1                           Makassar             NaN    Indonesia        APAC
# 2                           Shanghai             NaN        China        APAC
# 3                           Shanghai             NaN        China        APAC
# 4                           Shanghai             NaN        China        APAC
#
#   Origin BAF Region        ...          \
# 0          Far East        ...
# 1          Far East        ...
# 2          Far East        ...
# 3          Far East        ...
# 4          Far East        ...
#
#   POL post freetime Detention charge per day (USD)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   POL Combined post freetime charge per day (USD)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   POD DEMURRAGE Carriers Quote in calendar days  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   POD DETENTION Carriers Quote in calendar days  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   POD COMBINED demurrage/ detention Quote in calendar days  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   POD post freetime Demurrage charge per day (USD)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   POD post freetime Detention charge per day (USD)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   POD Combined post freetime charge per day (USD) Delete Bid  \
# 0                                             NaN        NaN
# 1                                             NaN        NaN
# 2                                             NaN        NaN
# 3                                             NaN        NaN
# 4                                             NaN        NaN
#
#   Jaggaer Identifier
# 0                101
# 1                102
# 2                103
# 3                104
# 4                105
#
# [5 rows x 91 columns]

# %% [markdown]
# As you can see, one format has nothing to do with the other one. We can see countries in ISO format whilst in the other one they introduce the whole country name, different equipment type spelling and so on. For this reason, I have temporally created a Template where the final user has to fill it in with the same format. Again, the idea is to store all different formats in a dictionary and improve this project so we do not have to manually create the tamplate.
#
# In this template, we have only selected the key columns that will allow us to apply Reverse Logistics.

# %%
Reverse_Logistics_Template = 'Reverse_Logistics_Template.xlsx'
RL_Template = pd.read_excel(Reverse_Logistics_Template)
RL_Template.head()
# Out:
#     Customer Lane_ID Origin_Country Destination_Country Origin_Port  \
# 0  CustomerB    1089             ID                  CN    Makassar
# 1  CustomerB    1090             ID                  CN    Makassar
# 2  CustomerB    1093             CN                  TH    Shanghai
# 3  CustomerB    1094             CN                  TH    Shanghai
# 4  CustomerB    1095             CN                  VN    Shanghai
#
#                          Destination_Port Origin_City Destination_City  \
# 0                         Xingang/Tianjin    Makassar          Xingang
# 1                                Shanghai    Makassar         Shanghai
# 2  Bangkok (Pat/Lat Krabang/Laem Chabang)    Shanghai          Bangkok
# 3  Bangkok (Pat/Lat Krabang/Laem Chabang)    Shanghai          Bangkok
# 4                                 Cat Lai    Shanghai      Ho Chi Minh
#
#      Equipment_Type Shipping_Terms      Commodity  Volume
# 0  20' Standard Dry   Port to Port   Cocoa Liquor    60.0
# 1  20' Standard Dry   Port to Port   Cocoa Liquor   140.0
# 2        20' Reefer   Port to Port  Confectionary    10.0
# 3        40' Reefer   Port to Port  Confectionary    70.0
# 4        20' Reefer   Port to Port  Confectionary     5.0

# %% [markdown]
# This is the format that from now on we are going to work on
