# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_root = '/home/dsc/TFM/Reverse_Logistics_Template.xlsx'
tender = pd.read_excel(file_root)
tender.head()
# Out:
#     Customer Lane_ID Origin_Country Destination_Country Origin_Port  \
# 0  CustomerB    1089             ID                  CN    Makassar
# 1  CustomerB    1090             ID                  CN    Makassar
# 2  CustomerB    1093             CN                  TH    Shanghai
# 3  CustomerB    1094             CN                  TH    Shanghai
# 4  CustomerB    1095             CN                  VN    Shanghai
#
#                          Destination_Port Origin_City Destination_City  \
# 0                         Xingang/Tianjin    Makassar          Xingang
# 1                                Shanghai    Makassar         Shanghai
# 2  Bangkok (Pat/Lat Krabang/Laem Chabang)    Shanghai          Bangkok
# 3  Bangkok (Pat/Lat Krabang/Laem Chabang)    Shanghai          Bangkok
# 4                                 Cat Lai    Shanghai      Ho Chi Minh
#
#      Equipment_Type Shipping_Terms      Commodity  Volume
# 0  20' Standard Dry   Port to Port   Cocoa Liquor    60.0
# ...

# %%
# !pip install googlemaps

# %%
import googlemaps

# %%
API_KEY = 'AIzaSyCb3tyT9hP3P5dpMSuOSJ51p_4i5d7-SqM'

# %%
map_client = googlemaps.Client(API_KEY)

# %%
casa = 'Norwich, United Kingdom'
response = map_client.geocode(casa)
print(response)
# Out:
# [{'address_components': [{'long_name': 'Norwich', 'short_name': 'Norwich', 'types': ['locality', 'political']}, {'long_name': 'Norwich', 'short_name': 'Norwich', 'types': ['postal_town']}, {'long_name': 'Norfolk', 'short_name': 'Norfolk', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}], 'formatted_address': 'Norwich, UK', 'geometry': {'bounds': {'northeast': {'lat': 52.6858357, 'lng': 1.3786135}, 'southwest': {'lat': 52.5944502, 'lng': 1.1950855}}, 'location': {'lat': 52.6308859, 'lng': 1.297355}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 52.6858357, 'lng': 1.3786135}, 'southwest': {'lat': 52.5944502, 'lng': 1.1950855}}}, 'place_id': 'ChIJE_UzUdWq0EcRL0USDuClTGg', 'types': ['locality', 'political']}]

# %%
print(response[0]['geometry']['bounds']['northeast']['lat'])
print(response[0]['geometry']['bounds']['northeast']['lng'])
# Out:
# 52.6858357
# 1.3786135

# %%
type(response)
# Out:
# list

# %%
tender.head()
# Out:
#     Customer Lane_ID Origin_Country Destination_Country Origin_Port  \
# 0  CustomerB    1089             ID                  CN    Makassar
# 1  CustomerB    1090             ID                  CN    Makassar
# 2  CustomerB    1093             CN                  TH    Shanghai
# 3  CustomerB    1094             CN                  TH    Shanghai
# 4  CustomerB    1095             CN                  VN    Shanghai
#
#                          Destination_Port Origin_City Destination_City  \
# 0                         Xingang/Tianjin    Makassar          Xingang
# 1                                Shanghai    Makassar         Shanghai
# 2  Bangkok (Pat/Lat Krabang/Laem Chabang)    Shanghai          Bangkok
# 3  Bangkok (Pat/Lat Krabang/Laem Chabang)    Shanghai          Bangkok
# 4                                 Cat Lai    Shanghai      Ho Chi Minh
#
#      Equipment_Type Shipping_Terms      Commodity  Volume
# 0  20' Standard Dry   Port to Port   Cocoa Liquor    60.0
# ...

# %%
# !pip install geopy

# %%
tender_sample = tender[['Lane_ID','Origin_City']].head()
tender_sample
# Out:
#   Lane_ID Origin_City
# 0    1089    Makassar
# 1    1090    Makassar
# 2    1093    Shanghai
# 3    1094    Shanghai
# 4    1095    Shanghai

# %%
for city in tender_sample['Origin_City']:
    tender_sample['location'] = map_client.geocode(city)[0]['geometry']['location']['lat']

# %%
tender_sample
# Out:
#   Lane_ID Origin_City   location
# 0    1089    Makassar  31.230416
# 1    1090    Makassar  31.230416
# 2    1093    Shanghai  31.230416
# 3    1094    Shanghai  31.230416
# 4    1095    Shanghai  31.230416

# %%
i = 0
for city in tender_sample['Origin_City']:
    tender_sample['location'].iloc[i] = map_client.geocode(city)[0]['geometry']['location']['lat']
    i += 1
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
tender_sample
# Out:
#   Lane_ID Origin_City   location
# 0    1089    Makassar  -5.147665
# 1    1090    Makassar  -5.147665
# 2    1093    Shanghai  31.230416
# 3    1094    Shanghai  31.230416
# 4    1095    Shanghai  31.230416

# %%
for city in tender_sample['Origin_City']:
    map_client.geocode(city)

# %%
tender_sample
# Out:
#   Lane_ID Origin_City   location
# 0    1089    Makassar  -5.147665
# 1    1090    Makassar  -5.147665
# 2    1093    Shanghai  31.230416
# 3    1094    Shanghai  31.230416
# 4    1095    Shanghai  31.230416

# %%
df = pd.DataFrame({'Lane_ID': [1,2,3], 'City': ['Manresa', 'Sabadell', 'Barcelona']})

# %%
type(df['City'].iloc[1])
# Out:
# str

# %%
def locations(a):
    i = 0
    for city in a['Origin_City']:
        a['Origin_City_lat'].iloc[i] = map_client.geocode(city)[0]['geometry']['bounds']['northeast']['lat']
        a['Origin_City_lon'].iloc[i] = map_client.geocode(city)[0]['geometry']['bounds']['northeast']['lon']
        i += 1
    i = 0
    for city in a['Destination_City']:
        a['Destination_City_lat'].iloc[i] = map_client.geocode(city)[0]['geometry']['bounds']['northeast']['lat']
        a['Destination_City_lon'].iloc[i] = map_client.geocode(city)[0]['geometry']['bounds']['northeast']['lon']

# %%
tender.head()
# Out:
#     Customer Lane_ID Origin_Country Destination_Country Origin_Port  \
# 0  CustomerB    1089             ID                  CN    Makassar
# 1  CustomerB    1090             ID                  CN    Makassar
# 2  CustomerB    1093             CN                  TH    Shanghai
# 3  CustomerB    1094             CN                  TH    Shanghai
# 4  CustomerB    1095             CN                  VN    Shanghai
#
#                          Destination_Port Origin_City Destination_City  \
# 0                         Xingang/Tianjin    Makassar          Xingang
# 1                                Shanghai    Makassar         Shanghai
# 2  Bangkok (Pat/Lat Krabang/Laem Chabang)    Shanghai          Bangkok
# 3  Bangkok (Pat/Lat Krabang/Laem Chabang)    Shanghai          Bangkok
# 4                                 Cat Lai    Shanghai      Ho Chi Minh
#
#      Equipment_Type Shipping_Terms      Commodity  Volume
# 0  20' Standard Dry   Port to Port   Cocoa Liquor    60.0
# ...

# %%
tender['Origin_City'].fillna("No City", inplace = True)

# %%
#Sacar uniques para hacer menos llamadas

# %%
i = 0
for city in tender['Origin_City']:
    if city == "No City":
        tender['Origin_City_Location'].iloc[i] = 0
    else:
        tender['Origin_City_Location'].iloc[i] = map_client.geocode(city)[0]['geometry']['location']['lat']
    i += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Origin_City_Location'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-eb6af64d0ee6> in <module>
# ...
