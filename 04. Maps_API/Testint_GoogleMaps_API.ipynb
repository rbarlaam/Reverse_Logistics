# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_root = '/home/dsc/TFM/Reverse_Logistics_Template.xlsx'
tender = pd.read_excel(file_root)
tender.head()
# Out:
#     Customer Lane_ID Origin_Country Destination_Country Origin_Port  \
# 0  CustomerB    1089             ID                  CN    Makassar
# 1  CustomerB    1090             ID                  CN    Makassar
# 2  CustomerB    1093             CN                  TH    Shanghai
# 3  CustomerB    1094             CN                  TH    Shanghai
# 4  CustomerB    1095             CN                  VN    Shanghai
#
#                          Destination_Port Origin_City Destination_City  \
# 0                         Xingang/Tianjin    Makassar          Xingang
# 1                                Shanghai    Makassar         Shanghai
# 2  Bangkok (Pat/Lat Krabang/Laem Chabang)    Shanghai          Bangkok
# 3  Bangkok (Pat/Lat Krabang/Laem Chabang)    Shanghai          Bangkok
# 4                                 Cat Lai    Shanghai      Ho Chi Minh
#
#      Equipment_Type Shipping_Terms      Commodity  Volume
# 0  20' Standard Dry   Port to Port   Cocoa Liquor    60.0
# ...

# %%
# !pip install googlemaps
# Out:
# ...
#   Running setup.py bdist_wheel for googlemaps ... done
#   Stored in directory: /home/dsc/.cache/pip/wheels/fb/24/33/51b0faba1170f6519eae3c51b6adbd9939296c73f54230b069
# Successfully built googlemaps
# ...

# %%
import googlemaps

# %%
API_KEY = 'AIzaSyCb3tyT9hP3P5dpMSuOSJ51p_4i5d7-SqM'

# %%
map_client = googlemaps.Client(API_KEY)

# %%
casa = 'Norwich, United Kingdom'
response = map_client.geocode(casa)
print(response)
# Out:
# [{'address_components': [{'long_name': 'Norwich', 'short_name': 'Norwich', 'types': ['locality', 'political']}, {'long_name': 'Norwich', 'short_name': 'Norwich', 'types': ['postal_town']}, {'long_name': 'Norfolk', 'short_name': 'Norfolk', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'England', 'short_name': 'England', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United Kingdom', 'short_name': 'GB', 'types': ['country', 'political']}], 'formatted_address': 'Norwich, UK', 'geometry': {'bounds': {'northeast': {'lat': 52.6858357, 'lng': 1.3786135}, 'southwest': {'lat': 52.5944502, 'lng': 1.1950855}}, 'location': {'lat': 52.6308859, 'lng': 1.297355}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 52.6858357, 'lng': 1.3786135}, 'southwest': {'lat': 52.5944502, 'lng': 1.1950855}}}, 'place_id': 'ChIJE_UzUdWq0EcRL0USDuClTGg', 'types': ['locality', 'political']}]

# %%
print(response[0]['geometry']['bounds']['northeast']['lat'])
print(response[0]['geometry']['bounds']['northeast']['lng'])
# Out:
# 52.6858357
# 1.3786135

# %%
type(response)
# Out:
# list
